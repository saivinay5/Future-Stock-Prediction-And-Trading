# %%
import math, random
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import torch.nn.functional as F
from torch.distributions import Categorical

# %%
torch.manual_seed(51)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# !pip install quandl
# Out:
# Requirement already satisfied: quandl in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.7/dist-packages (from quandl) (1.1.5)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from quandl) (2.23.0)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from quandl) (0.5.1)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.7/dist-packages (from quandl) (1.19.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from quandl) (2.8.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from quandl) (8.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from quandl) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.14->quandl) (2018.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (2021.10.8)

# %% [markdown]
# # Retrieve data from Quandl

# %%
import quandl
#quandl.ApiConfig.api_key = "xxx"
apl_stock=quandl.get('WIKI/AAPL', start_date="2014-01-01", end_date="2018-08-20", )
msf_stock=quandl.get('WIKI/MSFT', start_date="2014-01-01", end_date="2018-08-20")
apl_open = apl_stock["Open"].values
apl_close = apl_stock["Close"].values
msf_open = msf_stock["Open"].values
msf_close = msf_stock["Close"].values

# %%
#msf.head()

# %% [markdown]
# ## Examine the data

# %%
plt.plot(range(0, len(msf_open)), msf_open)

# %%
plt.plot(range(0, len(apl_open)), apl_open)

# %% [markdown]
# ## Handling the stock split

# %% [markdown]
# Turns out that on 9 June 2014, AAPL stock was split in the ratio of 1:7. So, I'll divide everything before element 108 in the stock array by 7 to correct for this.

# %%
apl_open[:108] /= 7

# %%
apl_close[:108] /= 7

# %%
plt.plot(range(0, len(apl_open)), apl_open)

# %% [markdown]
# ## Normalizing the Prices
#
# Now I'm going to de-trend the data. Otherwise MSFT and AAPL are on completely different scales and we could hardly expect the AI to learn how to trade apples and oranges together. Additionally, we want the AI to learn the fundamentals of the stock signal - buy if it's going to rise. If we didn't remove the trend, maybe it'd only learn to buy at the start and hold til the end since a general upwards trend happens.
#
# SciPy's signal processing module has a function that fits a linear least-squares model to the data and subtracts it for us.

# %%
from scipy import signal

# %%
msf_open = signal.detrend(msf_open)
msf_close = signal.detrend(msf_close)

# %%
plt.plot(range(0,len(msf_open)), msf_open)

# %%
apl_open = signal.detrend(apl_open)
apl_close = signal.detrend(apl_close)
plt.plot(range(0, len(apl_open)), apl_open)

# %% [markdown]
# ## Handling Negative values
#
# It doesn't make sense to buy a share at a negative value. But since the model will learn to maximize reward, we can just shift it up by a constant number so it's always positive.

# %%
print(apl_open.min())
print(apl_close.min())
print(msf_open.min())
print(msf_close.min())
# Out:
# -34.32168425572115
# -34.44741197813629
# -11.365775305682853
# -11.834602851531983

# %% [markdown]
# Choose 35

# %%
apl_open += 35.
apl_close += 35.
msf_open += 35.
msf_close += 35.

# %% [markdown]
# ## Save the transformed data

# %%
import pickle
with open("aplmsfopenclose.pkl", "wb+") as f:
    pickle.dump({"ao":apl_open, "ac": apl_close, "mo": msf_open, "mc": msf_close}, f)

# %% [markdown]
# ## If the data's already saved, skip the above and load it here instead

# %%
import pickle
with open("aplmsfopenclose.pkl", "rb") as f:
    d = pickle.load(f)
apl_open = d["ao"]
apl_close = d["ac"]
msf_open = d["mo"]
msf_close = d["mc"]

# %%
plt.plot(range(0,len(apl_open)), apl_open)

# %% [markdown]
# # Build the environment
#
# * For starting cash, we can't use a dollar value because of the transformed data. After shifting earlier, we know the mean of each opening price should be 35, so I'm starting the agent off with enough cash to buy ~2.5 shares.
# * This starting cash is the mean starting cash; it can be randomized by altering the std parameter
# * action space = 0 buy apple, 1 sell apple, 2 do nothing, 3 buy msft, 4 sell msft, quantity. eg. [0, 100]
# * obs space: apl shares, msft shares, cash in bank [2], today apl open [3], today msf open [4], portfolio value [5], 5 day window [6apl, 7msf] = 8
# * If bot gets to the end with more than one of each share, we give it a bonus for having a diversified portfolio!
# * Buys and sells attract a 10% brokerage fee

# %%
class TradingEnvironment():

    def __init__(self, starting_cash_mean=200., max_stride=5, series_length=208, starting_point=1, randomize_cash_std=0, \
                 starting_shares_mean=0., randomize_shares_std=0., inaction_penalty=0.):
        self.starting_shares_mean = starting_shares_mean
        self.randomize_shares_std = randomize_shares_std
        self.starting_cash_mean = starting_cash_mean
        self.randomize_cash_std = randomize_cash_std
        
        self.state = torch.FloatTensor(torch.zeros(8))
        
        self.starting_cash = max(int(np.random.normal(self.starting_cash_mean, self.randomize_cash_std)), 0.)
        
        self.series_length = series_length
        self.starting_point = starting_point
        self.cur_timestep = self.starting_point
        
        self.state[0] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.state[1] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.starting_portfolio_value = self.portfolio_value()
        self.state[2] = self.starting_cash
        self.state[3] = apl_open[self.cur_timestep]
        self.state[4] = msf_open[self.cur_timestep]
        self.state[5] = self.starting_portfolio_value
        self.state[6] = self.five_day_window()[0]
        self.state[7] = self.five_day_window()[1]
        
        self.max_stride = max_stride
        self.stride = self.max_stride # no longer varying it
        
        self.done = False
        self.diversification_bonus = 1.
        self.inaction_penalty = inaction_penalty
    
    def portfolio_value(self):
        return (self.state[0] * apl_close[self.cur_timestep]) + (self.state[1] * msf_close[self.cur_timestep]) + self.state[2]
    
    def next_opening_price(self):
        step = self.cur_timestep + self.stride
        return [apl_open[step], msf_open[step]]
    
    def five_day_window(self):
        step = self.cur_timestep
        if step < 5:
            return [apl_open[0], msf_open[0]]
        apl5 = apl_open[step-5:step].mean()
        msf5 = msf_open[step-5:step].mean()
        return [apl5, msf5]
    
    def step(self, action):
        action = [action, 1.]
        cur_timestep = self.cur_timestep
        ts_left = self.series_length - (cur_timestep - self.starting_point)
        retval = None
        cur_value = self.portfolio_value()
        gain = cur_value - self.starting_portfolio_value + (cur_timestep/self.series_length)
        #gain = cur_value - self.starting_portfolio_value - original implementation

        if cur_timestep >= self.starting_point + (self.series_length * self.stride):
            new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
            self.state = new_state
            bonus = 0.
            if self.state[0] > 0 and self.state[1] > 0:
                bonus = self.diversification_bonus
            return new_state, cur_value + bonus + gain, True, { "msg": "done"}
        
        if action[0] == 2:
            new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                    cur_value, *self.five_day_window()]
            self.state = new_state
            retval = new_state, -self.inaction_penalty-ts_left +gain, False, { "msg": "nothing" }
            
        if action[0] == 0:
            if action[1] * apl_open[cur_timestep] > self.state[2]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, -ts_left+gain/2, True, { "msg": "bankrupted self"}
            else:
                apl_shares = self.state[0] + action[1]
                cash_spent = action[1] * apl_open[cur_timestep] * 1.1
                new_state = [apl_shares, self.state[1], self.state[2] - cash_spent, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "bought AAPL"}
                
        if action[0] == 3:
            if action[1] * msf_open[cur_timestep] > self.state[2]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval =  new_state, -ts_left+gain/2, True, { "msg": "bankrupted self"}
            else:
                msf_shares = self.state[1] + action[1]
                cash_spent = action[1] * msf_open[cur_timestep] * 1.1
                new_state = [self.state[0], msf_shares, self.state[2] - cash_spent, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "bought MSFT"}
        

        if action[0] == 1:
            if action[1] > self.state[0]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, -ts_left+gain/2, True, { "msg": "sold more than have"}
            else:
                apl_shares = self.state[0] - action[1]
                cash_gained = action[1] * apl_open[cur_timestep] * 0.9
                new_state = [apl_shares, self.state[1], self.state[2] + cash_gained, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "sold AAPL"}
                
        if action[0] == 4:
            if action[1] > self.state[1]:
                new_state = [self.state[0], self.state[1], self.state[2], *self.next_opening_price(), \
                        cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, -ts_left+gain/2, True, { "msg": "sold more than have"}
            else:
                msf_shares = self.state[1] - action[1]
                cash_gained = action[1] * msf_open[cur_timestep] * 0.9
                new_state = [self.state[0], msf_shares, self.state[2] + cash_gained, *self.next_opening_price(), \
                       cur_value, *self.five_day_window()]
                self.state = new_state
                retval = new_state, self.inaction_penalty-ts_left+gain, False, { "msg": "sold MSFT"}
                
        self.cur_timestep += self.stride
        return retval
    
    def reset(self):
        self.state = torch.FloatTensor(torch.zeros(8))
        self.starting_cash = max(int(np.random.normal(self.starting_cash_mean, self.randomize_cash_std)), 0.)
        self.cur_timestep = self.starting_point
        self.state[0] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.state[1] = max(int(np.random.normal(self.starting_shares_mean, self.randomize_shares_std)), 0.)
        self.state[2] = self.starting_cash
        self.state[3] = apl_open[self.cur_timestep]
        self.state[4] = msf_open[self.cur_timestep]
        self.starting_portfolio_value = self.portfolio_value()
        self.state[5] = self.starting_portfolio_value
        self.state[6] = self.five_day_window()[0]
        self.state[7] = self.five_day_window()[1]       
        self.done = False
        return self.state

# %%
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.input_layer = nn.Linear(8,128).to(dtype=torch.float64)
        self.hidden_1 = nn.Linear(128, 128).to(dtype=torch.float64)
        self.hidden_2 = nn.Linear(32,31).to(dtype=torch.float64)
        self.hidden_state = torch.tensor(torch.zeros(2,1,32).to(dtype=torch.float64)).to(dtype=torch.float64)
        self.rnn = nn.GRU(128, 32, 2).to(dtype=torch.float64)
        self.action_head = nn.Linear(31, 5).to(dtype=torch.float64)
        self.value_head = nn.Linear(31, 1).to(dtype=torch.float64)
        self.saved_actions = []
        self.rewards = []

    def reset_hidden(self):
        self.hidden_state = torch.tensor(torch.zeros(2,1,32)).to(dtype=torch.float64)
        
    def forward(self, x):
        x = torch.tensor(x).to(dtype=torch.float64)
        x = torch.sigmoid(self.input_layer(x).to(dtype=torch.float64))
        x = torch.tanh((self.hidden_1(x.to(dtype=torch.float64)).to(dtype=torch.float64)))
        x=x.to(dtype=torch.float64)
        x, self.hidden_state = self.rnn(x.view(1,-1,128).to(dtype=torch.float64), (self.hidden_state.to(dtype=torch.float64)).data.to(dtype=torch.float64))
        x = F.relu(self.hidden_2(x.squeeze()))
        action_scores = self.action_head(x)
        state_values = self.value_head(x)
        return F.softmax(action_scores, dim=-1), state_values
    
    def act(self, state):
        probs, state_value = self.forward(state)
        m = Categorical(probs)
        action = m.sample()
        if action == 1 and env.state[0] < 1: action = torch.LongTensor([2]).squeeze()
        if action == 4 and env.state[1] < 1: action = torch.LongTensor([2]).squeeze()
        self.saved_actions.append((m.log_prob(action), state_value))
        return action.item()

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)
model = Policy().to(dtype=torch.float64)
optimizer = optim.Adam(model.parameters(), lr=3e-4)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   import sys

# %%
env.reset()
# In case you're running this a second time with the same model, delete the gradients
del model.rewards[:]
del model.saved_actions[:]

gamma = 0.9
log_interval = 60

def finish_episode():
    R = 0
    saved_actions = model.saved_actions
    policy_losses = []
    value_losses = []
    rewards = []
    for r in model.rewards[::-1]:
        R = r + (gamma * R)
        rewards.insert(0, R)
    rewards = torch.tensor(rewards)
    
    epsilon = (torch.rand(1) / 1e4) - 5e-5
    # With different architectures, I found the following standardization step sometimes
    # helpful, sometimes unhelpful.
    # rewards = (rewards - rewards.mean()) / (rewards.std(unbiased=False) + epsilon)
    # Alternatively, comment it out and use the following line instead:
    rewards += epsilon
    
    for (log_prob, value), r in zip(saved_actions, rewards):
        reward = torch.tensor(r - value.item())
        policy_losses.append(-log_prob * reward)
        value_losses.append(F.smooth_l1_loss(value, torch.tensor([r])))
        
    optimizer.zero_grad()
    loss = torch.stack(policy_losses).sum() + torch.stack(value_losses).sum()
    loss = torch.clamp(loss, -1e-5, 1e5)
    loss.backward()
    optimizer.step()
    del model.rewards[:]
    del model.saved_actions[:]

running_reward = 0
for episode in range(0, 4000):
    state = env.reset()
    reward = 0
    done = False
    msg = None
    while not done:
        action = model.act(state)
        state, reward, done, msg = env.step(action)
        model.rewards.append(reward)
        if done:
            break
    running_reward = running_reward * (1 - 1/log_interval) + reward * (1/log_interval)
    finish_episode()
    # Resetting the hidden state seems unnecessary - it's effectively random from the previous
    # episode anyway, more random than a bunch of zeros.
    # model.reset_hidden()
    if msg["msg"] == "done" and env.portfolio_value() > env.starting_portfolio_value * 1.1 and running_reward > 500:
        print("Early Stopping: " + str(int(reward)))
        break
    if episode % log_interval == 0:
        print("""Episode {}: started at {:.1f}, finished at {:.1f} because {} @ t={}, \
last reward {:.1f}, running reward {:.1f}""".format(episode, env.starting_portfolio_value, \
              env.portfolio_value(), msg["msg"], env.cur_timestep, reward, running_reward))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Episode 0: started at 7426.9, finished at 7423.0 because bankrupted self @ t=481, last reward 210.3, running reward 3.5
# Episode 60: started at 7677.2, finished at 7949.0 because bankrupted self @ t=381, last reward 614.8, running reward 425.2
# Episode 120: started at 8369.9, finished at 9178.6 because bankrupted self @ t=377, last reward 623.3, running reward 396.7
# Early Stopping: 11228

# %% [markdown]
# ## Training data
#
# ---

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)

total_rewards = 0
total_profits = 0
failed_goes = 0
num_goes = 50

for j in range(num_goes):
    env.reset()
    reward_this_go = -1e8
    for i in range(0,env.series_length + 1):
        action = model.act(env.state)
        next_state, reward, done, msg = env.step(action)
        if msg["msg"] == "done":
            reward_this_go = env.portfolio_value()
            break
        if done:
            break
    total_profits += (env.portfolio_value() - env.starting_portfolio_value) / env.starting_portfolio_value
    if reward_this_go == -1e8:
        failed_goes += 1
    else:
        total_rewards += reward_this_go

if failed_goes == num_goes:
    print("Failed all")
else:
    print("Failed goes: {} / {}, Avg Rewards per successful game: {}".format(failed_goes, num_goes, total_rewards / (num_goes - failed_goes)))
    print("Avg % profit per game: {}".format(total_profits / num_goes))
    print("Avg % profit per finished game: {}".format(total_profits / (num_goes - failed_goes)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Failed goes: 49 / 50, Avg Rewards per successful game: 9565.412109375
# Avg % profit per game: 0.01592104136943817
# Avg % profit per finished game: 0.796052098274231

# %% [markdown]
# ## sample trading run

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)
env.reset()
print("starting portfolio value {}".format(env.portfolio_value()))
for i in range(0,env.series_length + 1):
    action = model.act(env.state)
    next_state, reward, done, msg = env.step(action)
    if msg["msg"] == 'bankrupted self':
        print('bankrupted self by 1')
        break
    if msg["msg"] == 'sold more than have':
        print('sold more than have by 1')
        break
    print("{}, have {} aapl and {} msft and {} cash".format(msg["msg"], next_state[0], next_state[1], next_state[2]))
    if msg["msg"] == "done":
        print(next_state, reward)
        print("total portfolio value {}".format(env.portfolio_value()))
        break
# Out:
# starting portfolio value 8662.716796875
# bought MSFT, have 101.0 aapl and 116.0 msft and 1026.3057861328125 cash
# sold MSFT, have 101.0 aapl and 115.0 msft and 1060.7073974609375 cash
# sold AAPL, have 100.0 aapl and 115.0 msft and 1089.0771484375 cash
# nothing, have 100.0 aapl and 115.0 msft and 1089.0771484375 cash
# bought MSFT, have 100.0 aapl and 116.0 msft and 1047.35400390625 cash
# bought AAPL, have 101.0 aapl and 116.0 msft and 1021.620849609375 cash
# bought AAPL, have 102.0 aapl and 116.0 msft and 993.251708984375 cash
# bought AAPL, have 103.0 aapl and 116.0 msft and 963.109375 cash
# sold AAPL, have 102.0 aapl and 116.0 msft and 987.2999877929688 cash
# nothing, have 102.0 aapl and 116.0 msft and 987.2999877929688 cash
# sold AAPL, have 101.0 aapl and 116.0 msft and 1010.7215576171875 cash
# sold AAPL, have 100.0 aapl and 116.0 msft and 1033.547119140625 cash
# bought MSFT, have 100.0 aapl and 117.0 msft and 991.7060546875 cash
# sold AAPL, have 99.0 aapl and 117.0 msft and 1014.215087890625 cash
# bought AAPL, have 100.0 aapl and 117.0 msft and 984.4044189453125 cash
# bought AAPL, have 101.0 aapl and 117.0 msft and 956.283935546875 cash
# sold MSFT, have 101.0 aapl and 116.0 msft and 991.9549560546875 cash
# sold AAPL, have 100.0 aapl and 116.0 msft and 1012.0374145507812 cash
# sold AAPL, have 99.0 aapl and 116.0 msft and 1031.9918212890625 cash
# bought AAPL, have 100.0 aapl and 116.0 msft and 1000.3408813476562 cash
# sold AAPL, have 99.0 aapl and 116.0 msft and 1029.12158203125 cash
# sold MSFT, have 99.0 aapl and 115.0 msft and 1063.388671875 cash
# bought MSFT, have 99.0 aapl and 116.0 msft and 1021.2073974609375 cash
# sold AAPL, have 98.0 aapl and 116.0 msft and 1048.70263671875 cash
# sold MSFT, have 98.0 aapl and 115.0 msft and 1083.3892822265625 cash
# bought MSFT, have 98.0 aapl and 116.0 msft and 1041.34423828125 cash
# bought AAPL, have 99.0 aapl and 116.0 msft and 1001.0096435546875 cash
# sold MSFT, have 99.0 aapl and 115.0 msft and 1035.8817138671875 cash
# bought AAPL, have 100.0 aapl and 115.0 msft and 995.6825561523438 cash
# sold AAPL, have 99.0 aapl and 115.0 msft and 1028.6221923828125 cash
# bought MSFT, have 99.0 aapl and 116.0 msft and 985.5980224609375 cash
# bought AAPL, have 100.0 aapl and 116.0 msft and 943.7492065429688 cash
# bought AAPL, have 101.0 aapl and 116.0 msft and 900.4815063476562 cash
# bought AAPL, have 102.0 aapl and 116.0 msft and 856.0314331054688 cash
# sold AAPL, have 101.0 aapl and 116.0 msft and 890.5140380859375 cash
# sold AAPL, have 100.0 aapl and 116.0 msft and 926.4140625 cash
# sold MSFT, have 100.0 aapl and 115.0 msft and 961.9595947265625 cash
# sold AAPL, have 99.0 aapl and 115.0 msft and 995.4564208984375 cash
# sold MSFT, have 99.0 aapl and 114.0 msft and 1030.3756103515625 cash
# bought AAPL, have 100.0 aapl and 114.0 msft and 985.9483032226562 cash
# nothing, have 100.0 aapl and 114.0 msft and 985.9483032226562 cash
# bought MSFT, have 100.0 aapl and 115.0 msft and 941.9755859375 cash
# nothing, have 100.0 aapl and 115.0 msft and 941.9755859375 cash
# bought AAPL, have 101.0 aapl and 115.0 msft and 899.330810546875 cash
# sold MSFT, have 101.0 aapl and 114.0 msft and 936.3040161132812 cash
# sold MSFT, have 101.0 aapl and 113.0 msft and 973.93603515625 cash
# sold MSFT, have 101.0 aapl and 112.0 msft and 1010.1748657226562 cash
# sold MSFT, have 101.0 aapl and 111.0 msft and 1046.16357421875 cash
# nothing, have 101.0 aapl and 111.0 msft and 1046.16357421875 cash
# bought MSFT, have 101.0 aapl and 112.0 msft and 1004.7249755859375 cash
# bought AAPL, have 102.0 aapl and 112.0 msft and 963.9400634765625 cash
# sold AAPL, have 101.0 aapl and 112.0 msft and 1003.2314453125 cash
# bought AAPL, have 102.0 aapl and 112.0 msft and 953.5654296875 cash
# sold AAPL, have 101.0 aapl and 112.0 msft and 995.87158203125 cash
# nothing, have 101.0 aapl and 112.0 msft and 995.87158203125 cash
# bought MSFT, have 101.0 aapl and 113.0 msft and 949.5135498046875 cash
# nothing, have 101.0 aapl and 113.0 msft and 949.5135498046875 cash
# bought MSFT, have 101.0 aapl and 114.0 msft and 905.153076171875 cash
# sold AAPL, have 100.0 aapl and 114.0 msft and 952.17919921875 cash
# nothing, have 100.0 aapl and 114.0 msft and 952.17919921875 cash
# bought MSFT, have 100.0 aapl and 115.0 msft and 910.6610107421875 cash
# nothing, have 100.0 aapl and 115.0 msft and 910.6610107421875 cash
# bought MSFT, have 100.0 aapl and 116.0 msft and 867.5543823242188 cash
# sold AAPL, have 99.0 aapl and 116.0 msft and 906.5654907226562 cash
# bought AAPL, have 100.0 aapl and 116.0 msft and 854.380859375 cash
# bought AAPL, have 101.0 aapl and 116.0 msft and 805.4468994140625 cash
# sold MSFT, have 101.0 aapl and 115.0 msft and 838.8872680664062 cash
# sold MSFT, have 101.0 aapl and 114.0 msft and 868.8914794921875 cash
# bought AAPL, have 102.0 aapl and 114.0 msft and 811.54833984375 cash
# nothing, have 102.0 aapl and 114.0 msft and 811.54833984375 cash
# sold MSFT, have 102.0 aapl and 113.0 msft and 841.6480102539062 cash
# bought MSFT, have 102.0 aapl and 114.0 msft and 804.9122924804688 cash
# sold MSFT, have 102.0 aapl and 113.0 msft and 835.2406616210938 cash
# sold AAPL, have 101.0 aapl and 113.0 msft and 890.4147338867188 cash
# sold AAPL, have 100.0 aapl and 113.0 msft and 942.9111938476562 cash
# nothing, have 100.0 aapl and 113.0 msft and 942.9111938476562 cash
# sold AAPL, have 99.0 aapl and 113.0 msft and 996.5504760742188 cash
# sold AAPL, have 98.0 aapl and 113.0 msft and 1044.9921875 cash
# nothing, have 98.0 aapl and 113.0 msft and 1044.9921875 cash
# bought AAPL, have 99.0 aapl and 113.0 msft and 983.0139770507812 cash
# bought MSFT, have 99.0 aapl and 114.0 msft and 949.921142578125 cash
# bought MSFT, have 99.0 aapl and 115.0 msft and 917.10107421875 cash
# sold MSFT, have 99.0 aapl and 114.0 msft and 947.3306884765625 cash
# bought MSFT, have 99.0 aapl and 115.0 msft and 907.2351684570312 cash
# bought MSFT, have 99.0 aapl and 116.0 msft and 868.578369140625 cash
# sold MSFT, have 99.0 aapl and 115.0 msft and 899.3984985351562 cash
# sold AAPL, have 98.0 aapl and 115.0 msft and 950.5887451171875 cash
# bought AAPL, have 99.0 aapl and 115.0 msft and 884.7945556640625 cash
# nothing, have 99.0 aapl and 115.0 msft and 884.7945556640625 cash
# sold MSFT, have 99.0 aapl and 114.0 msft and 914.9199829101562 cash
# sold MSFT, have 99.0 aapl and 113.0 msft and 943.9852294921875 cash
# sold AAPL, have 98.0 aapl and 113.0 msft and 992.6774291992188 cash
# bought MSFT, have 98.0 aapl and 114.0 msft and 956.9508056640625 cash
# bought MSFT, have 98.0 aapl and 115.0 msft and 922.1679077148438 cash
# bought MSFT, have 98.0 aapl and 116.0 msft and 888.8677978515625 cash
# bought MSFT, have 98.0 aapl and 117.0 msft and 855.4664306640625 cash
# bought MSFT, have 98.0 aapl and 118.0 msft and 821.2378540039062 cash
# sold MSFT, have 98.0 aapl and 117.0 msft and 850.0728759765625 cash
# bought MSFT, have 98.0 aapl and 118.0 msft and 815.9498291015625 cash
# nothing, have 98.0 aapl and 118.0 msft and 815.9498291015625 cash
# sold AAPL, have 97.0 aapl and 118.0 msft and 852.3786010742188 cash
# bought AAPL, have 98.0 aapl and 118.0 msft and 811.9521484375 cash
# bought AAPL, have 99.0 aapl and 118.0 msft and 767.5493774414062 cash
# bought MSFT, have 99.0 aapl and 119.0 msft and 740.4441528320312 cash
# nothing, have 99.0 aapl and 119.0 msft and 740.4441528320312 cash
# bought AAPL, have 100.0 aapl and 119.0 msft and 701.3162231445312 cash
# sold AAPL, have 99.0 aapl and 119.0 msft and 731.0753784179688 cash
# bought AAPL, have 100.0 aapl and 119.0 msft and 688.438720703125 cash
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# nothing, have 100.0 aapl and 119.0 msft and 688.438720703125 cash
# sold AAPL, have 99.0 aapl and 119.0 msft and 720.6500244140625 cash
# bought MSFT, have 99.0 aapl and 120.0 msft and 690.7131958007812 cash
# bought MSFT, have 99.0 aapl and 121.0 msft and 658.453125 cash
# sold AAPL, have 98.0 aapl and 121.0 msft and 687.5906372070312 cash
# bought MSFT, have 98.0 aapl and 122.0 msft and 654.7540893554688 cash
# bought AAPL, have 99.0 aapl and 122.0 msft and 612.2998046875 cash
# sold AAPL, have 98.0 aapl and 122.0 msft and 649.3975219726562 cash
# bought AAPL, have 99.0 aapl and 122.0 msft and 603.4235229492188 cash
# nothing, have 99.0 aapl and 122.0 msft and 603.4235229492188 cash
# bought MSFT, have 99.0 aapl and 123.0 msft and 565.2628173828125 cash
# nothing, have 99.0 aapl and 123.0 msft and 565.2628173828125 cash
# bought MSFT, have 99.0 aapl and 124.0 msft and 525.9866333007812 cash
# nothing, have 99.0 aapl and 124.0 msft and 525.9866333007812 cash
# bought AAPL, have 100.0 aapl and 124.0 msft and 488.2853698730469 cash
# bought AAPL, have 101.0 aapl and 124.0 msft and 456.36474609375 cash
# nothing, have 101.0 aapl and 124.0 msft and 456.36474609375 cash
# sold AAPL, have 100.0 aapl and 124.0 msft and 478.2694091796875 cash
# bought MSFT, have 100.0 aapl and 125.0 msft and 439.73883056640625 cash
# sold AAPL, have 99.0 aapl and 125.0 msft and 453.9393005371094 cash
# bought AAPL, have 100.0 aapl and 125.0 msft and 439.9438171386719 cash
# sold MSFT, have 100.0 aapl and 124.0 msft and 467.8203125 cash
# sold AAPL, have 99.0 aapl and 124.0 msft and 476.5889587402344 cash
# bought AAPL, have 100.0 aapl and 124.0 msft and 464.8543395996094 cash
# sold MSFT, have 100.0 aapl and 123.0 msft and 490.0993347167969 cash
# sold MSFT, have 100.0 aapl and 122.0 msft and 516.8761596679688 cash
# bought AAPL, have 101.0 aapl and 122.0 msft and 504.64141845703125 cash
# bought MSFT, have 101.0 aapl and 123.0 msft and 470.43572998046875 cash
# bought MSFT, have 101.0 aapl and 124.0 msft and 436.018798828125 cash
# bought MSFT, have 101.0 aapl and 125.0 msft and 402.98565673828125 cash
# sold MSFT, have 101.0 aapl and 124.0 msft and 430.6266174316406 cash
# bought MSFT, have 101.0 aapl and 125.0 msft and 396.489013671875 cash
# sold MSFT, have 101.0 aapl and 124.0 msft and 425.1236267089844 cash
# bought AAPL, have 102.0 aapl and 124.0 msft and 401.3672790527344 cash
# bought AAPL, have 103.0 aapl and 124.0 msft and 376.6375732421875 cash
# sold AAPL, have 102.0 aapl and 124.0 msft and 397.3793640136719 cash
# bought MSFT, have 102.0 aapl and 125.0 msft and 360.5025634765625 cash
# bought MSFT, have 102.0 aapl and 126.0 msft and 329.15655517578125 cash
# bought AAPL, have 103.0 aapl and 126.0 msft and 323.2373352050781 cash
# nothing, have 103.0 aapl and 126.0 msft and 323.2373352050781 cash
# sold AAPL, have 102.0 aapl and 126.0 msft and 327.1081237792969 cash
# sold AAPL, have 101.0 aapl and 126.0 msft and 331.685302734375 cash
# bought MSFT, have 101.0 aapl and 127.0 msft and 302.6161193847656 cash
# bought AAPL, have 102.0 aapl and 127.0 msft and 292.2700500488281 cash
# bought MSFT, have 102.0 aapl and 128.0 msft and 261.6343994140625 cash
# sold AAPL, have 101.0 aapl and 128.0 msft and 268.74017333984375 cash
# bought AAPL, have 102.0 aapl and 128.0 msft and 261.1169738769531 cash
# bought MSFT, have 102.0 aapl and 129.0 msft and 233.46661376953125 cash
# bought MSFT, have 102.0 aapl and 130.0 msft and 207.22203063964844 cash
# bought MSFT, have 102.0 aapl and 131.0 msft and 178.94021606445312 cash
# bought AAPL, have 103.0 aapl and 131.0 msft and 174.03453063964844 cash
# bought MSFT, have 103.0 aapl and 132.0 msft and 143.16323852539062 cash
# bought AAPL, have 104.0 aapl and 132.0 msft and 135.0238037109375 cash
# bought MSFT, have 104.0 aapl and 133.0 msft and 101.5960464477539 cash
# nothing, have 104.0 aapl and 133.0 msft and 101.5960464477539 cash
# bought AAPL, have 105.0 aapl and 133.0 msft and 87.50048828125 cash
# bought MSFT, have 105.0 aapl and 134.0 msft and 52.99903106689453 cash
# bought AAPL, have 106.0 aapl and 134.0 msft and 36.417724609375 cash
# sold MSFT, have 106.0 aapl and 133.0 msft and 64.20884704589844 cash
# bought AAPL, have 107.0 aapl and 133.0 msft and 50.98279571533203 cash
# nothing, have 107.0 aapl and 133.0 msft and 50.98279571533203 cash
# bought MSFT, have 107.0 aapl and 134.0 msft and 18.824172973632812 cash
# sold AAPL, have 106.0 aapl and 134.0 msft and 35.39167785644531 cash
# nothing, have 106.0 aapl and 134.0 msft and 35.39167785644531 cash
# bought AAPL, have 107.0 aapl and 134.0 msft and 16.715761184692383 cash
# bankrupted self by 1

# %%
apl_open_orig = apl_stock["Open"].values
apl_close_orig = apl_stock["Close"].values
msf_open_orig = msf_stock["Open"].values
msf_close_orig = msf_stock["Close"].values
apl_open_orig[:108] /= 7
apl_close_orig[:108] /= 7

# %%
env = TradingEnvironment(max_stride=4, series_length=250, starting_cash_mean=1000, randomize_cash_std=100, starting_shares_mean=100, randomize_shares_std=10)
env.reset()
complete_game = False
while not complete_game:
    bought_apl_at = []
    bought_msf_at = []
    sold_apl_at = []
    sold_msf_at = []
    bought_apl_at_orig = []
    bought_msf_at_orig = []
    sold_apl_at_orig = []
    sold_msf_at_orig = []
    nothing_at = []
    ba_action_times = []
    bm_action_times = []
    sa_action_times = []
    sm_action_times = []
    n_action_times = []
    starting_val = env.starting_portfolio_value
    print("Starting portfolio value: {}".format(starting_val))
    for i in range(0,env.series_length + 1):
        action = model.act(env.state)
        if action == 0:
            bought_apl_at.append(apl_open[env.cur_timestep])
            bought_apl_at_orig.append(apl_open_orig[env.cur_timestep])
            ba_action_times.append(env.cur_timestep)
        if action == 1:
            sold_apl_at.append(apl_close[env.cur_timestep])
            sold_apl_at_orig.append(apl_close_orig[env.cur_timestep])
            sa_action_times.append(env.cur_timestep)
        if action == 2:
            nothing_at.append(35)
            n_action_times.append(env.cur_timestep)
        if action == 3:
            bought_msf_at.append(msf_open[env.cur_timestep])
            bought_msf_at_orig.append(msf_open_orig[env.cur_timestep])
            bm_action_times.append(env.cur_timestep)
        if action == 4:
            sold_msf_at.append(msf_close[env.cur_timestep])
            sold_msf_at_orig.append(msf_close_orig[env.cur_timestep])
            sm_action_times.append(env.cur_timestep)
        next_state, reward, done, msg = env.step(action)
        if msg["msg"] == 'bankrupted self':
            env.reset()
            break
        if msg["msg"] == 'sold more than have':
            env.reset()
            break
        if msg["msg"] == "done":
            print("{}, have {} aapl and {} msft and {} cash".format(msg["msg"], next_state[0], next_state[1], next_state[2]))
            val = env.portfolio_value()
            print("Finished portfolio value {}".format(val))
            if val > starting_val * 1.1: complete_game = True
            env.reset()
            break
# Out:
# Starting portfolio value: 7669.92724609375
# Starting portfolio value: 8403.4990234375
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Starting portfolio value: 6921.3828125
# Starting portfolio value: 7563.99609375
# Starting portfolio value: 7272.9921875
# Starting portfolio value: 8864.935546875
# Starting portfolio value: 8388.3212890625
# Starting portfolio value: 8376.25
# Starting portfolio value: 7918.60546875
# Starting portfolio value: 7881.4609375
# Starting portfolio value: 8669.7197265625
# Starting portfolio value: 7944.78271484375
# Starting portfolio value: 7260.0283203125
# Starting portfolio value: 8982.2939453125
# Starting portfolio value: 7746.6767578125
# Starting portfolio value: 8231.8564453125
# Starting portfolio value: 6843.5224609375
# Starting portfolio value: 7823.78271484375
# Starting portfolio value: 7332.20751953125
# Starting portfolio value: 7077.45361328125
# Starting portfolio value: 8111.216796875
# Starting portfolio value: 9411.5830078125
# Starting portfolio value: 8425.359375
# Starting portfolio value: 8034.1748046875
# Starting portfolio value: 6922.48828125
# Starting portfolio value: 7126.2763671875
# Starting portfolio value: 7725.888671875
# Starting portfolio value: 7668.70703125
# Starting portfolio value: 9189.1884765625
# Starting portfolio value: 7863.4619140625
# Starting portfolio value: 8437.5712890625
# Starting portfolio value: 8022.9970703125
# Starting portfolio value: 7644.173828125
# Starting portfolio value: 8945.8271484375
# Starting portfolio value: 8319.0712890625
# Starting portfolio value: 8151.89111328125
# Starting portfolio value: 9009.361328125
# Starting portfolio value: 8273.5703125
# Starting portfolio value: 7980.927734375
# Starting portfolio value: 7986.5341796875
# Starting portfolio value: 7778.70703125
# Starting portfolio value: 8130.927734375
# Starting portfolio value: 7475.6376953125
# Starting portfolio value: 7731.8193359375
# Starting portfolio value: 7839.3896484375
# Starting portfolio value: 7695.2451171875
# Starting portfolio value: 8361.642578125
# done, have 99.0 aapl and 104.0 msft and 399.4390869140625 cash
# Finished portfolio value 10099.107421875

# %%
plt.figure(1, figsize=(14,5))
apl = plt.subplot(121)
msf = plt.subplot(122)
apl.plot(range(0, len(apl_open)), apl_open)
msf.plot(range(0, len(msf_open)), msf_open)
apl.plot(ba_action_times, bought_apl_at, "ro")
apl.plot(sa_action_times, sold_apl_at, "go")
apl.plot(n_action_times, nothing_at, "yx")
msf.plot(n_action_times, nothing_at, "yx")
msf.plot(bm_action_times, bought_msf_at, "ro")
msf.plot(sm_action_times, sold_msf_at, "go")
